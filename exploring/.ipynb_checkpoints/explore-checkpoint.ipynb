# %%
import numpy as np 
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
text = cv2.imread('../data/text1.jpg')

# %%
plt.figure(figsize=(50,40))
plt.imshow(text)

# %%
gray.shape
# Out:
# (903, 638)

# %%
gray = cv2.cvtColor(text, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(50,40))
plt.imshow(text)

# %%
scale_percent = 40
width = int(text.shape[1] * scale_percent / 100)
height = int(text.shape[0] * scale_percent / 100)
dim = (width, height)
text_res = cv2.resize(text,dim, interpolation = cv2.INTER_AREA)

plt.figure(figsize=(30,20))

plt.imshow(text_res)

# %%
line_interval = [510,540]
plt.figure(figsize=(30,20))

plt.imshow(text[line_interval[0]:line_interval[1],:])

# %%
text_res
# Out:
# array([[255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 247,
#         205, 238, 243, 237, 246, 226, 227, 238, 228, 236, 222, 237, 226,
#         242, 197, 252, 207, 246, 226, 242, 197, 251, 226, 228, 236, 208,
#         243, 225, 233, 243, 236, 235, 238, 255, 255, 255, 255, 252, 209,
#         226, 225, 247, 225, 233, 241, 215, 246, 218, 247, 225, 233, 240,
#         214, 245, 232, 239, 218, 251, 208, 249, 208, 247, 226, 246, 224,
#         252, 215, 246, 218, 254, 255, 255, 255, 254, 230, 229, 236, 234,
#         238, 255, 255, 255, 255, 253, 197, 242, 223, 252, 226, 228, 235,
#         229, 228, 246, 225, 233, 243, 227, 241, 208, 236, 254, 255, 255,
#         255, 228, 243, 235, 239, 228, 236, 222, 244, 255, 255, 255, 255,
#         247, 228, 239, 246, 232, 239, 218, 226, 220, 229, 239, 238, 253,
#         216, 246, 217, 227, 220, 251, 226, 227, 236, 208, 248, 208, 253,
#         228, 236, 222, 241, 210, 226, 225, 254, 255, 255, 255, 255, 236,
#         235, 238, 228, 243, 235, 237, 216, 247, 217, 251, 214, 245, 229,
#         239, 238, 227, 235, 231, 254, 255, 255, 255, 255, 222, 235, 248,
#         226, 246, 223, 217, 220, 231, 249, 227, 235, 231, 227, 236, 222,
#         244, 255, 255, 255, 255, 252, 229, 229, 252, 208, 251, 215, 247,
#         215, 247, 217, 252, 207, 251, 196, 250, 226, 228, 238, 226, 235,
#         247, 208, 252, 208, 247, 222, 230, 242, 254, 240, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255]], dtype=uint8)

# %%
scale_percent = 100
width = int(gray.shape[1]*50/100)
height = 1
dim = (width, height)
text_res = cv2.resize(gray[line_interval[0]:line_interval[1],:],dim, interpolation = cv2.INTER_AREA)

plt.figure(figsize=(30,200))

plt.imshow(text_res)

# %%
plt.plot(np.arange(0,text_res.shape[1]),text_res.reshape(-1))

# %%
text_res.shape[1]
# Out:
# 319
